# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQVxZjjmaH1oKVXmwyc0YGcXyyzTeiEfUBXQvbNUC0rKgUtpZ09lQ
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSombkMePFeLrCUV042HidTHKtoqdFTlERwSGEENG-rMbjaa-ATzA
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLZTEr8rgZLA3O_HB34JVytLpBs0QXVPzcT2WB3qmYxPsfQTgDjA
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLE11MpCfP4TzQbI3h6TE0aCm_kRO29FV1RClx3dxgzeqHXtl46g
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRheDfqzr_x4os60MPFah-q5ulHomCmTG8LHcBCAHui_EkA87Jn
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVGTH7upPp2OP-Rvsm-1MVoC7oRz2Cdgp3nxZQhmCNMfHmHP4Ghw
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS5mL0DDvtdRtYZCKgS1-qUiq7tRo9pqGpLALHmyKIDk4kEV6jA
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsPUT4OucpZMlQRRHrcMWubQpQKwbSVZie5kra8Z7gzEtk32yD0g
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSrlAsTMnVk-4SlYzOTCQil1H2ZBPaxRwhIWxyOt3FlOfUbFzpl7A
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3pKh5dPaltmapctTYHFjtmJZU6oISAK_t9ywTrg7vm9xZTslB
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScnZvd57NagHO9aiNxKLw5rnuNJlclVwaxwMOioUB1AwWzldUK
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRvHA5h0kFYuv50SpmVlVPsVd8mnDJ9Bxp-yV1QPyyASeC9He5Pgw
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_1FvoVMLcayiJow-Y4T4ADuxqgbQpk-pkbBST3U53gTmQBu2c
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWm-6OFf5f8vqTilQPHkVQK_VsrdEutmkO3LFFAAiFpd2L7Xvk
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSy2UP_jXi-xFDlS157XYOQmKWDR_xM8H55Jew31HrDbzLS0XV2pQ
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_l3zk3PBua5h2GotwgAHOg31vVoSTJ1c94mGjYt5322JZy_pkEg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMtrIQ7oqwk7YxWufemiuNVjdaYf4RfHHPpqxA8QIEDA7OfYTt
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOxSKqlfcIMvbki7zVHirpB6hkuxPswXy6CUfsnEmDiqvBQxla
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTPefLxEDEOmo9taDKVaXjpVMbNC1YxATDJISyk1son6sZ1LBIC5g

# %%
with open('1.jpg', 'wb') as f:
    res = requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRenJ2NhFqaqhsaDLFa06pNtqKgY_A_WwRmgH4QZrYpmsEPcAsFNQ')
    f.write(res.content)

# %%
dataurl = 'https://www.google.com/search?ei=d3IqXMGIG8y4sQWzuo2IDw&yv=3&q={}&tbm=isch&vet=10ahUKEwiBoPyI68rfAhVMXKwKHTNdA_EQuT0IOSgB.d3IqXMGIG8y4sQWzuo2IDw.i&ved=0ahUKEwiBoPyI68rfAhVMXKwKHTNdA_EQuT0IOSgB&ijn=1&start={}&asearch=ichunk&async=_id:rg_s,_pms:s,_fmt:pc'
def getIdolImg(keyword, dstpath):
    for i in range(1):
        res = requests.get(dataurl.format(keyword,i*100))
        soup = BeautifulSoup(res.text, 'lxml')
        for ele in soup.select('img'):
            imageurl = ele.get('src')
            fname = imageurl.split('tbn:')[1]
            with open(dstpath + fname + '.jpg', 'wb') as f:
                res2 = requests.get(imageurl)
                f.write(res2.content)

# %%
import os
os.mkdir('idol1/')

# %%
getIdolImg('鈕承澤', 'idol1/')

# %%
import os
os.listdir('idol1')[0:8]
# Out:
# ['ANd9GcQ4RmDmDwEVskMlCg53N5cREt2Mw2PwPi1mnimBweZMDc-qjBEq.jpg',
#  'ANd9GcQ8knGbcCVQY37W8jGYmciflPB7i3YtAwS7h7IZtg-KI7F3ZJpbFg.jpg',
#  'ANd9GcTf0I10rW0Ut6MZGRCjhPJ5UUwjMLSgI_gAHn6l3yvYbZlIj452tg.jpg',
#  'ANd9GcR4eOzDASTIZWnlYoisjJNrJlRULMaETnUaPGYCRAaWOBLbKAPe.jpg',
#  'ANd9GcRVNkzbXgY-OP22Zs-Nig13JYoKpT4nuWS9ZdMc1rMJ-x4xAzUx.jpg',
#  'ANd9GcSZ68DsQ5f5rwK3xbNmpEN57DM9td20NFteUC7_WPL3Z7BYjJaq.jpg',
#  'ANd9GcT8tpHCZGK47BsyMyOZl_jRRpf_ASGYwH8HIrp1DazTc36RcTUk.jpg',
#  'ANd9GcR_rRi7rKTE95extIJhYW0BUJTIi2H9x7QhAunLNb7ShqKA4gueMQ.jpg']

# %%
from PIL import Image
img = Image.open('idol1/ANd9GcR4eOzDASTIZWnlYoisjJNrJlRULMaETnUaPGYCRAaWOBLbKAPe.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x244 at 0x11BDE1240>

# %%
import cv2 as cv
imgary = cv.imread('idol1/ANd9GcR4eOzDASTIZWnlYoisjJNrJlRULMaETnUaPGYCRAaWOBLbKAPe.jpg')

# %%
imgary
# Out:
# array([[[109,  95,  89],
#         [110,  96,  90],
#         [110,  96,  90],
#         ...,
#         [131, 117, 111],
#         [131, 117, 111],
#         [131, 117, 111]],
#
#        [[110,  96,  90],
#         [110,  96,  90],
#         [110,  96,  90],
#         ...,
#         [131, 117, 111],
#         [131, 117, 111],
#         [131, 117, 111]],
#
#        [[110,  96,  90],
#         [110,  96,  90],
#         [110,  96,  90],
#         ...,
#         [131, 117, 111],
#         [131, 117, 111],
#         [131, 117, 111]],
#
#        ...,
#
#        [[244, 239, 238],
#         [246, 241, 240],
#         [248, 243, 242],
#         ...,
#         [170, 153, 144],
#         [170, 153, 144],
#         [170, 153, 144]],
#
#        [[245, 240, 239],
#         [246, 241, 240],
#         [247, 242, 241],
#         ...,
#         [170, 153, 144],
#         [170, 153, 144],
#         [170, 153, 144]],
#
#        [[246, 241, 240],
#         [246, 241, 240],
#         [246, 241, 240],
#         ...,
#         [170, 153, 144],
#         [170, 153, 144],
#         [170, 153, 144]]], dtype=uint8)

# %%
imgary.shape
# Out:
# (244, 183, 3)

# %%
face_cascade = cv.CascadeClassifier('/usr/local/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# %%
faces = face_cascade.detectMultiScale(imgary, 1.3, 5)

# %%
faces
# Out:
# array([[54, 46, 98, 98]], dtype=int32)

# %%
x,y,w,h = faces[0]

# %%
crpim = img.crop((x,y, x + w, y + h)).resize((64,64))
crpim
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x11CF43160>

# %%
import os
os.mkdir('idol1_face/')

# %%
import os
srcpath = 'idol1/' 
dstpath = 'idol1_face/'
face_cascade = cv.CascadeClassifier('/usr/local/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')
for fname in os.listdir(srcpath):
    img = Image.open(srcpath + fname)
    imgary = cv.imread(srcpath + fname)
    faces = face_cascade.detectMultiScale(imgary, 1.3, 5)
    if len(faces) == 1:
        x,y,w,h = faces[0]
        crpim = img.crop((x,y, x + w, y + h)).resize((64,64))
        crpim.save(dstpath + fname)
    #print(srcpath + fname)

# %%
os.listdir(dstpath)[0:5]
# Out:
# ['ANd9GcQ4RmDmDwEVskMlCg53N5cREt2Mw2PwPi1mnimBweZMDc-qjBEq.jpg',
#  'ANd9GcTf0I10rW0Ut6MZGRCjhPJ5UUwjMLSgI_gAHn6l3yvYbZlIj452tg.jpg',
#  'ANd9GcR4eOzDASTIZWnlYoisjJNrJlRULMaETnUaPGYCRAaWOBLbKAPe.jpg',
#  'ANd9GcRVNkzbXgY-OP22Zs-Nig13JYoKpT4nuWS9ZdMc1rMJ-x4xAzUx.jpg',
#  'ANd9GcSZ68DsQ5f5rwK3xbNmpEN57DM9td20NFteUC7_WPL3Z7BYjJaq.jpg']

# %%
Image.open('idol1_face/ANd9GcQ4RmDmDwEVskMlCg53N5cREt2Mw2PwPi1mnimBweZMDc-qjBEq.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64 at 0x11CDDA828>

# %%
import os
import requests
from bs4 import BeautifulSoup
dataurl = 'https://www.google.com/search?ei=d3IqXMGIG8y4sQWzuo2IDw&yv=3&q={}&tbm=isch&vet=10ahUKEwiBoPyI68rfAhVMXKwKHTNdA_EQuT0IOSgB.d3IqXMGIG8y4sQWzuo2IDw.i&ved=0ahUKEwiBoPyI68rfAhVMXKwKHTNdA_EQuT0IOSgB&ijn=1&start={}&asearch=ichunk&async=_id:rg_s,_pms:s,_fmt:pc'

def getIdolImg(keyword, dstpath):
    for i in range(6):
        res = requests.get(dataurl.format(keyword, i * 100))
        soup = BeautifulSoup(res.text, 'lxml')
        for ele in soup.select('img'):
            imgurl = ele.get('src')
            fname  = imgurl.split('tbn:')[1]
            with open(dstpath + fname + '.jpg', 'wb') as f:
                res2 = requests.get(imgurl)
                f.write(res2.content)

# %%
if not os.path.exists('NiuChenZer/'):
    os.mkdir('NiuChenZer/')
getIdolImg('鈕承澤', 'NiuChenZer/')

# %%
if not os.path.exists('ChuChungHeng'):
    os.mkdir('ChuChungHeng/')
getIdolImg('屈中恆', 'ChuChungHeng/')

# %%
if not os.path.exists('SungShaoChing'):
    os.mkdir('SungShaoChing/')
getIdolImg('宋少卿', 'SungShaoChing/')

# %%
import cv2 as cv
from PIL import Image

def extractFace(srcpath, dstpath):
    if not os.path.exists(srcpath):
        os.mkdir(srcpath)
    if not os.path.exists(dstpath):
        os.mkdir(dstpath)
    face_cascade = cv.CascadeClassifier('/usr/local/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')
    for fname in os.listdir(srcpath):
        img = Image.open(srcpath + fname)
        imgary = cv.imread(srcpath + fname)
        faces = face_cascade.detectMultiScale(imgary, 1.3, 5)
        if len(faces) == 1:
            x,y,w,h = faces[0]
            crpim = img.crop((x,y, x + w, y + h)).resize((64,64))
            crpim.save(dstpath + fname)

# %%
srcpath = 'NiuChenZer/' 
dstpath = 'NiuChenZerFace/'
extractFace(srcpath, dstpath)

# %%
srcpath = 'ChuChungHeng/' 
dstpath = 'ChuChungHengFace/'
extractFace(srcpath, dstpath)

# %%
srcpath = 'SungShaoChing/' 
dstpath = 'SungShaoChingFace/'
extractFace(srcpath, dstpath)

# %%
! pip3 install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (1.9.0)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (0.32.1)
# Requirement already satisfied: astor>=0.6.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: six>=1.10.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: absl-py>=0.1.6 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (0.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.4.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (3.6.1)
# Requirement already satisfied: gast>=0.2.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (0.2.0)
# Collecting setuptools<=39.1.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/8c/10/79282747f9169f21c053c562a0baa21815a8c7879be97abd930dbcf862e8/setuptools-39.1.0-py2.py3-none-any.whl
# Requirement already satisfied: tensorboard<1.10.0,>=1.9.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (1.9.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorflow) (1.15.2)
# Requirement already satisfied: werkzeug>=0.11.10 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (3.0.1)
# Installing collected packages: setuptools
#   Found existing installation: setuptools 40.6.3
#     Uninstalling setuptools-40.6.3:
#       Successfully uninstalled setuptools-40.6.3
# Successfully installed setuptools-39.1.0

# %%
! pip3 install keras
# Out:
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#     100% |████████████████████████████████| 317kB 7.4MB/s ta 0:00:01
# Requirement already satisfied: six>=1.9.0 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from keras) (1.11.0)
# Collecting scipy>=0.14 (from keras)
#   Downloading https://files.pythonhosted.org/packages/c0/1d/eef9d7b34ab8b7ee42d570f2e24d58ee0374064c1ca593bdb02914f66a80/scipy-1.2.0-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (28.8MB)
#     100% |████████████████████████████████| 28.8MB 523kB/s eta 0:00:01  2% |▊                               | 634kB 6.9MB/s eta 0:00:05    3% |█                               | 870kB 12.2MB/s eta 0:00:03    36% |███████████▋                    | 10.4MB 9.6MB/s eta 0:00:02
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/site-packages (from keras) (1.0.5)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/site-packages (from keras) (1.0.6)
# Requirement already satisfied: numpy>=1.9.1 in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from keras) (1.15.2)
# Requirement already satisfied: pyyaml in /Users/APPLE/Library/Python/3.6/lib/python/site-packages (from keras) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/site-packages (from keras) (2.8.0)
# Installing collected packages: scipy, keras
# Successfully installed keras-2.2.4 scipy-1.2.0

# %%
from keras.models import Sequential 
from keras.layers import Conv2D
from keras.layers import MaxPooling2D 
from keras.layers import Flatten
from keras.layers import Dense

# Initialising the CNN
classifier = Sequential()

# Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64,
3), activation = 'relu'))

# Max Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Convolution
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))

# Max Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))


# Flattening
classifier.add(Flatten())

# Fully Connected
classifier.add(Dense(units = 128, activation = 'relu')) 
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 3, activation = 'softmax'))

classifier.compile(optimizer = 'adam', 
                        loss ='categorical_crossentropy', 
                     metrics = ['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,     
                                   zoom_range = 0.2,      
                                   horizontal_flip = True 
                                  )

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(
    'training/', target_size = (64, 64),
     batch_size = 10,
     class_mode = 'categorical')
# Out:
# Found 330 images belonging to 3 classes.

# %%
test_set = test_datagen.flow_from_directory(
    'testing/', target_size = (64, 64),
    batch_size = 10, 
    class_mode = 'categorical')
# Out:
# Found 85 images belonging to 3 classes.

# %%
history = classifier.fit_generator(training_set,
                         nb_epoch=10,
                         nb_val_samples=10,
                         steps_per_epoch = 30,
                         verbose = 1,
                         validation_data = test_set)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=30, verbose=1, validation_data=<keras_pre..., epochs=10, validation_steps=10)`
# Epoch 1/10
# 30/30 [==============================] - 4s 140ms/step - loss: 1.0670 - acc: 0.5233 - val_loss: 1.0535 - val_acc: 0.5158
# Epoch 2/10
# 30/30 [==============================] - 3s 115ms/step - loss: 1.0360 - acc: 0.5167 - val_loss: 1.0468 - val_acc: 0.4842
# Epoch 3/10
# 30/30 [==============================] - 4s 117ms/step - loss: 1.0125 - acc: 0.5133 - val_loss: 1.0173 - val_acc: 0.4842
# Epoch 4/10
# 30/30 [==============================] - 3s 95ms/step - loss: 0.9161 - acc: 0.5833 - val_loss: 0.9186 - val_acc: 0.6000
# Epoch 5/10
# 30/30 [==============================] - 3s 99ms/step - loss: 0.9124 - acc: 0.5800 - val_loss: 1.0434 - val_acc: 0.5789
# Epoch 6/10
# 30/30 [==============================] - 3s 97ms/step - loss: 0.8240 - acc: 0.6300 - val_loss: 1.1261 - val_acc: 0.4947
# Epoch 7/10
# 30/30 [==============================] - 3s 88ms/step - loss: 0.8392 - acc: 0.6200 - val_loss: 0.8663 - val_acc: 0.6000
# Epoch 8/10
# 30/30 [==============================] - 3s 89ms/step - loss: 0.8062 - acc: 0.6500 - val_loss: 1.0906 - val_acc: 0.5474
# Epoch 9/10
# 30/30 [==============================] - 3s 90ms/step - loss: 0.8846 - acc: 0.6233 - val_loss: 0.9510 - val_acc: 0.5556
# Epoch 10/10
# 30/30 [==============================] - 3s 93ms/step - loss: 0.7486 - acc: 0.6800 - val_loss: 1.0955 - val_acc: 0.5368

# %%
from PIL import Image
im = Image.open('whoami.jpg')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=906x914 at 0x13463BFD0>

# %%
from PIL import Image
import cv2 as cv
face_cascade = cv.CascadeClassifier('/usr/local/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_default.xml')

img = cv.imread('whoami.jpg')
faces = face_cascade.detectMultiScale(img, 1.2, 3)
faces
# Out:
# array([[702,  33,  97,  97],
#        [ 47,  60,  94,  94],
#        [424,  42,  76,  76],
#        [354, 369, 203, 203],
#        [125, 361, 101, 101],
#        [688, 349, 190, 190],
#        [125, 628,  91,  91],
#        [658, 647, 163, 163],
#        [394, 673, 123, 123]], dtype=int32)

# %%
transform_dic = {
    'ChuChungHengFace'  : 'Chu Chung-Heng',
    'NiuChenZerFace'    : 'Niu Chen-Zer',
    'SungShaoChingFace' : 'Sung Shao-Ching'
}
name_dic = {v:transform_dic.get(k) for k,v in training_set.class_indices.items()}
name_dic
# Out:
# {0: 'Chu Chung-Heng', 1: 'Niu Chen-Zer', 2: 'Sung Shao-Ching'}

# %%
from keras.preprocessing import image
import numpy as np
from matplotlib import pyplot as plt 
font = cv.FONT_HERSHEY_PLAIN
for x,y,w,h in faces:
    box = (x, y, x+w, y+h)
    crpim = im.crop(box).resize((64,64))
    target_image = image.img_to_array(crpim)
    target_image = np.expand_dims(target_image, axis = 0)
    res = classifier.predict_classes(target_image)[0]
    cv.rectangle(img,(x,y),(x+w,y+h),(14,201,255),2)
    cv.putText(img,name_dic.get(res), (x + int(w/3)-70, y-10), font, 1.5, (14,201,255), 3)

# %%
# %pylab inline
plt.figure(figsize=(30,20))
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
# Out:
# Populating the interactive namespace from numpy and matplotlib
